# %%
import os
import numpy as np
import netCDF4
import datetime
import logging
import cmocean
import calendar
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
logger = logging.getLogger("ClimComparison")
logger.setLevel(logging.INFO)
logging.info("Sarting")

# %% [markdown]
# ## Files and directories

# %%
datadir1 = "/home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/output/"
datadir2 = "/data/SeaDataCloud/NorthSea/Climato/"
figdir = "/home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/"
if not os.path.exists(figdir):
    os.mkdir(figdir)

# %%
# Path to the products to be compared
# Old products
salinity_month_sdn = os.path.join(datadir2, "Salinity.19002015.4Danl.nc")
temperature_month_sdn = os.path.join(datadir2, "Temperature.19002015.4Danl.nc")

# Annual products
# New products, only SDC data
temperature_year_sdc0 = os.path.join(datadir1, "SDN/Water_body_Temperature_NorthSea.4Danl_annual.nc")
salinity_year_sdc0 = os.path.join(datadir1, "SDN/Water_body_Salinity_NorthSea.4Danl_annual.nc")
logger.info(os.path.exists(temperature_year_sdc1) & os.path.exists(salinity_year_sdc1))

# New products, SDc + WOD data, without coefficients derivative
temperature_year_sdc1 = os.path.join(datadir1, "Water_body_Temperature_NorthSea.4Danl_annual_merged.nc")
salinity_year_sdc1 = os.path.join(datadir1, "Water_body_Salinity_NorthSea.4Danl_annual_merged.nc")
logger.info(os.path.exists(temperature_year_sdc1) & os.path.exists(salinity_year_sdc1))

# New products with coefficient
temperature_year_sdc2 = os.path.join(datadir1, "Water_body_Temperature_NorthSea.4Danl_annual_merged_coeffderiv.nc")
salinity_year_sdc2 = os.path.join(datadir1, "Water_body_Salinity_NorthSea.4Danl_annual_merged_coeffderiv.nc")
# Out:
# INFO:ClimComparison:True
# INFO:ClimComparison:True

# %% [markdown]
# ## Reading & plotting functions

# %%
def read_climato(filename, varname):
    """
    Read the climatology from the netCDF file `filename`.
    """
    if varname.lower() == "temperature":
        std_name = "sea_water_temperature"
    elif varname.lower() == "salinity":
        std_name = "sea_water_salinity"
    
    with netCDF4.Dataset(filename, "r") as nc:
        lon = nc.variables["lon"][:]
        lat = nc.variables["lat"][:]
        depth = nc.variables["depth"][:]
        ttime = nc.variables["time"][:]
        timeunits = nc.variables["time"].units
        dates = netCDF4.num2date(ttime, timeunits)
        try:
            field = nc.get_variables_by_attributes(standard_name=std_name)[0][:]
        except :
            field = nc.get_variables_by_attributes(long_name=varname.capitalize())[0][:]
        
    return lon, lat, depth, dates, field

# %%
def make_plot_2Dfield(lon1, lat1, lon2, lat2, field1, field2, figtitle, 
                      figname, subtitle1="",subtitle2="", **kwargs):
    
    if varname.lower() == "temperature":
        cb_label = "T ($^{\circ}$C)"
        vmin = 7.5
        vmax = 17.5
        cmap = cmocean.cm.thermal
    elif varname.lower() == "salinity":
        cb_label = "S"
        vmin = 30.
        vmax = 40.
        cmap = cmocean.cm.haline
    else:
        logger.error("Unknown variable")
    
    fig = plt.figure(figsize=(12, 6))
    ax1 = plt.subplot(121)
    m.pcolormesh(lon1, lat1, field1, latlon=True, 
                 cmap=cmap, vmin=vmin, vmax=vmax)
    m.drawmeridians(np.arange(-5., lon1.max(), 3.), labels=[0,1,0,1], 
                    linewidth=0.5, zorder=2, fontsize=14)
    m.drawparallels(np.arange(48., lat1.max(), 2.), labels=[1,0,1,0], 
                    linewidth=0.5, zorder=2, fontsize=14)
    m.drawcoastlines(linewidth=0.2, zorder=4)
    m.fillcontinents(color=".75", zorder=3)
    cb = plt.colorbar(extend="both", shrink=.9)
    cb.set_label(cb_label, rotation=0, ha="left", fontsize=14)
    plt.title(subtitle1)

    plt.subplot(122)
    m.pcolormesh(lon2, lat2, field2, latlon=True,
                cmap=cmap, vmin=vmin, vmax=vmax)
    m.drawmeridians(np.arange(-5., lon1.max(), 3.), labels=[0,1,0,1], 
                    linewidth=0.5, zorder=2, fontsize=14)
    m.drawparallels(np.arange(48., lat1.max(), 2.), labels=[1,0,1,0], 
                    linewidth=0.5, zorder=2, fontsize=14)
    m.drawcoastlines(linewidth=0.25, zorder=5)
    m.fillcontinents(color=".75", zorder=3)
    cb = plt.colorbar(extend="both", shrink=.9)
    cb.set_label(cb_label, rotation=0, ha="left", fontsize=14)
    plt.title(subtitle2)
    fig.suptitle(figtitle, fontsize=14)
    plt.savefig(figname, dpi=300, bbox_inches="tight")
    #plt.show()
    plt.close()

# %% [markdown]
# ## Comparisons
# ### 1. Field with and without coefficients

# %%
lon1, lat1, depth1, dates1, T1 = read_climato(temperature_year_sdc1, "temperature")
lon2, lat2, depth2, dates2, T2 = read_climato(temperature_year_sdc2, "temperature")
lon1, lat1, depth1, dates1, S1 = read_climato(salinity_year_sdc1, "salinity")
lon2, lat2, depth2, dates2, S2 = read_climato(salinity_year_sdc2, "salinity")

# %%
m = Basemap(projection='merc',llcrnrlat=lat1.min(), urcrnrlat=lat1.max(),
            llcrnrlon=-5.5, urcrnrlon=lon1.max(),lat_ts=lat1.mean(), resolution='i')

# %%
llon1, llat1 = np.meshgrid(lon1, lat1)
llon2, llat2 = np.meshgrid(lon2, lat2)
varname = "salinity"
figdir = "./NorthSea/figures/Comparison/2-coeffderiv/"

if not os.path.exists(figdir):
    os.makedirs(figdir)
    
# Select the common depth
depth_common = np.intersect1d(depth1, depth2)

# Loop on depths
for d in depth_common:
    ind1 = np.where(d == depth1)[0]
    ind2 = np.where(d == depth2)[0]
    logger.info((ind1, ind2))
    
    
    field1 = S1[0, ind1, :, :].squeeze()
    field2 = S2[0, ind2, :, :].squeeze()

    mm = "00"
    dd = str(int(d)).zfill(3)

    figname = os.path.join(figdir, "{0}_{1}_{2}".format(varname,mm, dd))
    figtitle = "Annual $-$ {} m".format(d)
    logger.info(figtitle)
    logger.info("Working on {}".format(figname))
    make_plot_2Dfield(llon1, llat1, llon2, llat2, field1, field2, figtitle, 
                      figname, 
                      subtitle1="Without coeff_derivative2",
                      subtitle2="coeff_derivative2 = [0.0, 0.0, 1e-8]")
# Out:
# INFO:ClimComparison:(array([0]), array([0]))
# INFO:ClimComparison:Annual $-$ 0.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_000
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3413: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3422: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# INFO:ClimComparison:(array([1]), array([1]))
# INFO:ClimComparison:Annual $-$ 5.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_005
# INFO:ClimComparison:(array([2]), array([2]))
# INFO:ClimComparison:Annual $-$ 10.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_010
# INFO:ClimComparison:(array([3]), array([3]))
# INFO:ClimComparison:Annual $-$ 15.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_015
# INFO:ClimComparison:(array([4]), array([4]))
# INFO:ClimComparison:Annual $-$ 20.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_020
# INFO:ClimComparison:(array([5]), array([5]))
# INFO:ClimComparison:Annual $-$ 25.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_025
# INFO:ClimComparison:(array([6]), array([6]))
# INFO:ClimComparison:Annual $-$ 30.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_030
# INFO:ClimComparison:(array([7]), array([7]))
# INFO:ClimComparison:Annual $-$ 35.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_035
# INFO:ClimComparison:(array([8]), array([8]))
# INFO:ClimComparison:Annual $-$ 40.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_040
# INFO:ClimComparison:(array([9]), array([9]))
# INFO:ClimComparison:Annual $-$ 45.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_045
# INFO:ClimComparison:(array([10]), array([10]))
# INFO:ClimComparison:Annual $-$ 50.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_050
# INFO:ClimComparison:(array([11]), array([11]))
# INFO:ClimComparison:Annual $-$ 55.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_055
# INFO:ClimComparison:(array([12]), array([12]))
# INFO:ClimComparison:Annual $-$ 60.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_060
# INFO:ClimComparison:(array([13]), array([13]))
# INFO:ClimComparison:Annual $-$ 65.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_065
# INFO:ClimComparison:(array([14]), array([14]))
# INFO:ClimComparison:Annual $-$ 70.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_070
# INFO:ClimComparison:(array([15]), array([15]))
# INFO:ClimComparison:Annual $-$ 75.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_075
# INFO:ClimComparison:(array([16]), array([16]))
# INFO:ClimComparison:Annual $-$ 80.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_080
# INFO:ClimComparison:(array([17]), array([17]))
# INFO:ClimComparison:Annual $-$ 85.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_085
# INFO:ClimComparison:(array([18]), array([18]))
# INFO:ClimComparison:Annual $-$ 90.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_090
# INFO:ClimComparison:(array([19]), array([19]))
# INFO:ClimComparison:Annual $-$ 95.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_095
# INFO:ClimComparison:(array([20]), array([20]))
# INFO:ClimComparison:Annual $-$ 100.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_100
# INFO:ClimComparison:(array([21]), array([21]))
# INFO:ClimComparison:Annual $-$ 125.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_125
# INFO:ClimComparison:(array([22]), array([22]))
# INFO:ClimComparison:Annual $-$ 150.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_150
# INFO:ClimComparison:(array([23]), array([23]))
# INFO:ClimComparison:Annual $-$ 175.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_175
# INFO:ClimComparison:(array([24]), array([24]))
# INFO:ClimComparison:Annual $-$ 200.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_200
# INFO:ClimComparison:(array([25]), array([25]))
# INFO:ClimComparison:Annual $-$ 225.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_225
# INFO:ClimComparison:(array([26]), array([26]))
# INFO:ClimComparison:Annual $-$ 250.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_250
# INFO:ClimComparison:(array([27]), array([27]))
# INFO:ClimComparison:Annual $-$ 275.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_275
# INFO:ClimComparison:(array([28]), array([28]))
# INFO:ClimComparison:Annual $-$ 300.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_300
# INFO:ClimComparison:(array([29]), array([29]))
# INFO:ClimComparison:Annual $-$ 325.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_325
# INFO:ClimComparison:(array([30]), array([30]))
# INFO:ClimComparison:Annual $-$ 350.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_350
# INFO:ClimComparison:(array([31]), array([31]))
# INFO:ClimComparison:Annual $-$ 375.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_375
# INFO:ClimComparison:(array([32]), array([32]))
# INFO:ClimComparison:Annual $-$ 400.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_400
# INFO:ClimComparison:(array([33]), array([33]))
# INFO:ClimComparison:Annual $-$ 425.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_425
# INFO:ClimComparison:(array([34]), array([34]))
# INFO:ClimComparison:Annual $-$ 450.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_450
# INFO:ClimComparison:(array([35]), array([35]))
# INFO:ClimComparison:Annual $-$ 475.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_475
# INFO:ClimComparison:(array([36]), array([36]))
# INFO:ClimComparison:Annual $-$ 500.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_500
# INFO:ClimComparison:(array([37]), array([37]))
# INFO:ClimComparison:Annual $-$ 550.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_550
# INFO:ClimComparison:(array([38]), array([38]))
# INFO:ClimComparison:Annual $-$ 600.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_600
# INFO:ClimComparison:(array([39]), array([39]))
# INFO:ClimComparison:Annual $-$ 650.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_650
# INFO:ClimComparison:(array([40]), array([40]))
# INFO:ClimComparison:Annual $-$ 700.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/2-coeffderiv/salinity_00_700

# %% [markdown]
# ## 2. Difference when using different dataset
# 1. SDC only
# 2. SDC + World Ocean Atlas

# %% [markdown]
# ### Read the fields

# %%
lon0, lat0, depth0, dates0, T0 = read_climato(temperature_year_sdc0, "temperature")
lon0, lat0, depth0, dates0, S0 = read_climato(salinity_year_sdc0, "salinity")

# %% [markdown]
# ### Make the comparative plots

# %%
llon0, llat0 = np.meshgrid(lon1, lat1)
varname = "salinity"
figdir = "./NorthSea/figures/Comparison/3-sdn_wod/"

if not os.path.exists(figdir):
    os.makedirs(figdir)

# Loop on depths
for idepth, d in enumerate(depth0):
   
    field1 = S0[0, idepth, :, :].squeeze()
    field2 = S1[0, idepth, :, :].squeeze()

    mm = "00"
    dd = str(int(d)).zfill(3)

    figname = os.path.join(figdir, "{0}_{1}_{2}".format(varname,mm, dd))
    figtitle = "Annual $-$ {} m".format(d)
    logger.info(figtitle)
    logger.info("Working on {}".format(figname))
    make_plot_2Dfield(llon0, llat0, llon0, llat0, field1, field2, figtitle, figname,
                     subtitle1="SeaDataNet observations only",
                     subtitle2="SeaDataNet and World Ocean Database")
# Out:
# INFO:ClimComparison:Annual $-$ 0.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_000
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3413: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3422: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# INFO:ClimComparison:Annual $-$ 5.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_005
# INFO:ClimComparison:Annual $-$ 10.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_010
# INFO:ClimComparison:Annual $-$ 15.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_015
# INFO:ClimComparison:Annual $-$ 20.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_020
# INFO:ClimComparison:Annual $-$ 25.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_025
# INFO:ClimComparison:Annual $-$ 30.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_030
# INFO:ClimComparison:Annual $-$ 35.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_035
# INFO:ClimComparison:Annual $-$ 40.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_040
# INFO:ClimComparison:Annual $-$ 45.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_045
# INFO:ClimComparison:Annual $-$ 50.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_050
# INFO:ClimComparison:Annual $-$ 55.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_055
# INFO:ClimComparison:Annual $-$ 60.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_060
# INFO:ClimComparison:Annual $-$ 65.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_065
# INFO:ClimComparison:Annual $-$ 70.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_070
# INFO:ClimComparison:Annual $-$ 75.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_075
# INFO:ClimComparison:Annual $-$ 80.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_080
# INFO:ClimComparison:Annual $-$ 85.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_085
# INFO:ClimComparison:Annual $-$ 90.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_090
# INFO:ClimComparison:Annual $-$ 95.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_095
# INFO:ClimComparison:Annual $-$ 100.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_100
# INFO:ClimComparison:Annual $-$ 125.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_125
# INFO:ClimComparison:Annual $-$ 150.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_150
# INFO:ClimComparison:Annual $-$ 175.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_175
# INFO:ClimComparison:Annual $-$ 200.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_200
# INFO:ClimComparison:Annual $-$ 225.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_225
# INFO:ClimComparison:Annual $-$ 250.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_250
# INFO:ClimComparison:Annual $-$ 275.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_275
# INFO:ClimComparison:Annual $-$ 300.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_300
# INFO:ClimComparison:Annual $-$ 325.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_325
# INFO:ClimComparison:Annual $-$ 350.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_350
# INFO:ClimComparison:Annual $-$ 375.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_375
# INFO:ClimComparison:Annual $-$ 400.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_400
# INFO:ClimComparison:Annual $-$ 425.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_425
# INFO:ClimComparison:Annual $-$ 450.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_450
# INFO:ClimComparison:Annual $-$ 475.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_475
# INFO:ClimComparison:Annual $-$ 500.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_500
# INFO:ClimComparison:Annual $-$ 550.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_550
# INFO:ClimComparison:Annual $-$ 600.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_600
# INFO:ClimComparison:Annual $-$ 650.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_650
# INFO:ClimComparison:Annual $-$ 700.0 m
# INFO:ClimComparison:Working on ./NorthSea/figures/Comparison/3-sdn_wod/salinity_00_700

# %% [markdown]
# ## Read fields from the old and new products for T and S

# %%
lon1, lat1, depth1, dates1, T1 = read_climato(temperature_month_sdn, "temperature")
lon2, lat2, depth2, dates2, T2 = read_climato(temperature_month_sdc, "temperature")
lon1, lat1, depth1, dates1, S1 = read_climato(salinity_month_sdn, "salinity")
lon2, lat2, depth2, dates2, S2 = read_climato(salinity_month_sdc, "salinity")
logger.info(S1.shape)
logger.info(S2.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7942008399e5> in <module>()
# ----> 1 lon1, lat1, depth1, dates1, T1 = read_climato(temperature_month_sdn, "temperature")
#       2 lon2, lat2, depth2, dates2, T2 = read_climato(temperature_month_sdc, "temperature")
#       3 lon1, lat1, depth1, dates1, S1 = read_climato(salinity_month_sdn, "salinity")
#       4 lon2, lat2, depth2, dates2, S2 = read_climato(salinity_month_sdc, "salinity")
#       5 logger.info(S1.shape)
#
# NameError: name 'temperature_month_sdn' is not defined

# %%
llon1, llat1 = np.meshgrid(lon1, lat1)
llon2, llat2 = np.meshgrid(lon2, lat2)

# %%
# Select the common depth
depth_common = np.intersect1d(depth1, depth2)

# Loop on depths
for d in depth_common:
    ind1 = np.where(d == depth1)[0]
    ind2 = np.where(d == depth2)[0]
    logger.info((ind1, ind2))
    
    # Loop on month
    for months in range(0, 12):
        field1 = S1[months, ind1, :, :].squeeze()
        field2 = S2[months, ind2, :, :].squeeze()
        
        mm = str(months+1).zfill(2)
        dd = str(int(d)).zfill(3)
        
        
        figname = os.path.join(figdir, "salinity_{0}_{1}".format(mm, dd))
        figtitle = "{} $-$ {} m".format(calendar.month_name[months+1], d)
        logger.info(figtitle)
        logger.info("Working on {}".format(figname))
        make_plot_2Dfield(llon1, llat1, llon2, llat2, field1, field2, figtitle, figname)
# Out:
# INFO:ClimComparison:(array([13]), array([0]))
# INFO:ClimComparison:January $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_000
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3413: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3422: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/ctroupin/Software/PythonEnvs/Diva-python3.6/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# INFO:ClimComparison:February $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_000
# INFO:ClimComparison:March $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_000
# INFO:ClimComparison:April $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_000
# INFO:ClimComparison:May $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_000
# INFO:ClimComparison:June $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_000
# INFO:ClimComparison:July $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_000
# INFO:ClimComparison:August $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_000
# INFO:ClimComparison:September $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_000
# INFO:ClimComparison:October $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_000
# INFO:ClimComparison:November $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_000
# INFO:ClimComparison:December $-$ 0.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_000
# INFO:ClimComparison:(array([12]), array([2]))
# INFO:ClimComparison:January $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_010
# INFO:ClimComparison:February $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_010
# INFO:ClimComparison:March $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_010
# INFO:ClimComparison:April $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_010
# INFO:ClimComparison:May $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_010
# INFO:ClimComparison:June $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_010
# INFO:ClimComparison:July $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_010
# INFO:ClimComparison:August $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_010
# INFO:ClimComparison:September $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_010
# INFO:ClimComparison:October $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_010
# INFO:ClimComparison:November $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_010
# INFO:ClimComparison:December $-$ 10.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_010
# INFO:ClimComparison:(array([11]), array([4]))
# INFO:ClimComparison:January $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_020
# INFO:ClimComparison:February $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_020
# INFO:ClimComparison:March $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_020
# INFO:ClimComparison:April $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_020
# INFO:ClimComparison:May $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_020
# INFO:ClimComparison:June $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_020
# INFO:ClimComparison:July $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_020
# INFO:ClimComparison:August $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_020
# INFO:ClimComparison:September $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_020
# INFO:ClimComparison:October $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_020
# INFO:ClimComparison:November $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_020
# INFO:ClimComparison:December $-$ 20.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_020
# INFO:ClimComparison:(array([10]), array([6]))
# INFO:ClimComparison:January $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_030
# INFO:ClimComparison:February $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_030
# INFO:ClimComparison:March $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_030
# INFO:ClimComparison:April $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_030
# INFO:ClimComparison:May $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_030
# INFO:ClimComparison:June $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_030
# INFO:ClimComparison:July $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_030
# INFO:ClimComparison:August $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_030
# INFO:ClimComparison:September $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_030
# INFO:ClimComparison:October $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_030
# INFO:ClimComparison:November $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_030
# INFO:ClimComparison:December $-$ 30.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_030
# INFO:ClimComparison:(array([9]), array([10]))
# INFO:ClimComparison:January $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_050
# INFO:ClimComparison:February $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_050
# INFO:ClimComparison:March $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_050
# INFO:ClimComparison:April $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_050
# INFO:ClimComparison:May $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_050
# INFO:ClimComparison:June $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_050
# INFO:ClimComparison:July $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_050
# INFO:ClimComparison:August $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_050
# INFO:ClimComparison:September $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_050
# INFO:ClimComparison:October $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_050
# INFO:ClimComparison:November $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_050
# INFO:ClimComparison:December $-$ 50.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_050
# INFO:ClimComparison:(array([8]), array([15]))
# INFO:ClimComparison:January $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_075
# INFO:ClimComparison:February $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_075
# INFO:ClimComparison:March $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_075
# INFO:ClimComparison:April $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_075
# INFO:ClimComparison:May $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_075
# INFO:ClimComparison:June $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_075
# INFO:ClimComparison:July $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_075
# INFO:ClimComparison:August $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_075
# INFO:ClimComparison:September $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_075
# INFO:ClimComparison:October $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_075
# INFO:ClimComparison:November $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_075
# INFO:ClimComparison:December $-$ 75.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_075
# INFO:ClimComparison:(array([7]), array([20]))
# INFO:ClimComparison:January $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_100
# INFO:ClimComparison:February $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_100
# INFO:ClimComparison:March $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_100
# INFO:ClimComparison:April $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_100
# INFO:ClimComparison:May $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_100
# INFO:ClimComparison:June $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_100
# INFO:ClimComparison:July $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_100
# INFO:ClimComparison:August $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_100
# INFO:ClimComparison:September $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_100
# INFO:ClimComparison:October $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_100
# INFO:ClimComparison:November $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_100
# INFO:ClimComparison:December $-$ 100.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_100
# INFO:ClimComparison:(array([6]), array([21]))
# INFO:ClimComparison:January $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_125
# INFO:ClimComparison:February $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_125
# INFO:ClimComparison:March $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_125
# INFO:ClimComparison:April $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_125
# INFO:ClimComparison:May $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_125
# INFO:ClimComparison:June $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_125
# INFO:ClimComparison:July $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_125
# INFO:ClimComparison:August $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_125
# INFO:ClimComparison:September $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_125
# INFO:ClimComparison:October $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_125
# INFO:ClimComparison:November $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_125
# INFO:ClimComparison:December $-$ 125.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_125
# INFO:ClimComparison:(array([5]), array([22]))
# INFO:ClimComparison:January $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_150
# INFO:ClimComparison:February $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_150
# INFO:ClimComparison:March $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_150
# INFO:ClimComparison:April $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_150
# INFO:ClimComparison:May $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_150
# INFO:ClimComparison:June $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_150
# INFO:ClimComparison:July $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_150
# INFO:ClimComparison:August $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_150
# INFO:ClimComparison:September $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_150
# INFO:ClimComparison:October $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_150
# INFO:ClimComparison:November $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_150
# INFO:ClimComparison:December $-$ 150.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_150
# INFO:ClimComparison:(array([4]), array([24]))
# INFO:ClimComparison:January $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_200
# INFO:ClimComparison:February $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_200
# INFO:ClimComparison:March $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_200
# INFO:ClimComparison:April $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_200
# INFO:ClimComparison:May $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_200
# INFO:ClimComparison:June $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_200
# INFO:ClimComparison:July $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_200
# INFO:ClimComparison:August $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_200
# INFO:ClimComparison:September $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_200
# INFO:ClimComparison:October $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_200
# INFO:ClimComparison:November $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_200
# INFO:ClimComparison:December $-$ 200.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_200
# INFO:ClimComparison:(array([3]), array([26]))
# INFO:ClimComparison:January $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_250
# INFO:ClimComparison:February $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_250
# INFO:ClimComparison:March $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_250
# INFO:ClimComparison:April $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_250
# INFO:ClimComparison:May $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_250
# INFO:ClimComparison:June $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_250
# INFO:ClimComparison:July $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_250
# INFO:ClimComparison:August $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_250
# INFO:ClimComparison:September $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_250
# INFO:ClimComparison:October $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_250
# INFO:ClimComparison:November $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_250
# INFO:ClimComparison:December $-$ 250.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_250
# INFO:ClimComparison:(array([2]), array([28]))
# INFO:ClimComparison:January $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_300
# INFO:ClimComparison:February $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_300
# INFO:ClimComparison:March $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_300
# INFO:ClimComparison:April $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_300
# INFO:ClimComparison:May $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_300
# INFO:ClimComparison:June $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_300
# INFO:ClimComparison:July $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_300
# INFO:ClimComparison:August $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_300
# INFO:ClimComparison:September $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_300
# INFO:ClimComparison:October $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_300
# INFO:ClimComparison:November $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_300
# INFO:ClimComparison:December $-$ 300.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_300
# INFO:ClimComparison:(array([1]), array([32]))
# INFO:ClimComparison:January $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_400
# INFO:ClimComparison:February $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_400
# INFO:ClimComparison:March $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_400
# INFO:ClimComparison:April $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_400
# INFO:ClimComparison:May $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_400
# INFO:ClimComparison:June $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_400
# INFO:ClimComparison:July $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_400
# INFO:ClimComparison:August $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_400
# INFO:ClimComparison:September $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_400
# INFO:ClimComparison:October $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_400
# INFO:ClimComparison:November $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_400
# INFO:ClimComparison:December $-$ 400.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_400
# INFO:ClimComparison:(array([0]), array([36]))
# INFO:ClimComparison:January $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_01_500
# INFO:ClimComparison:February $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_02_500
# INFO:ClimComparison:March $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_03_500
# INFO:ClimComparison:April $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_04_500
# INFO:ClimComparison:May $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_05_500
# INFO:ClimComparison:June $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_06_500
# INFO:ClimComparison:July $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_07_500
# INFO:ClimComparison:August $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_08_500
# INFO:ClimComparison:September $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_09_500
# INFO:ClimComparison:October $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_10_500
# INFO:ClimComparison:November $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_11_500
# INFO:ClimComparison:December $-$ 500.0 m
# INFO:ClimComparison:Working on /home/ctroupin/Projects/SeaDataCloud/Julia/Climatologies/NorthSea/figures/Comparison/salinity_12_500
