# %%
using PhysOcean
using Glob
using PyPlot
# Out:
# ┌ Info: Recompiling stale cache file /home/ctroupin/.julia/compiled/v1.1/PyPlot/oatAj.ji for PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1184

# %%
datadir = "/data/CORA/"
# Out:
# "/data/CORA/"

# %%
filelist = glob("*.nc", datadir);
@show size(filelist)
# Out:
# size(filelist) = (434,)
# (434,)

# %%
obsdata, obslon, obslat, obsz, obstime, obsids = ARGO.load(Float64, filelist, "TEMP");

# %%
scatter(obslon, obslat, c=obsdata, s=1);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f70bc8a44a8>)
